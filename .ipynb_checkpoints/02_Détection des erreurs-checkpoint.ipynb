# %% [markdown]
# # Etude des trajectoires

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import numpy as np
from mpl_toolkits.mplot3d import axes3d

# %%
def show_2D(df, msg=""):
    plt.title("id_traj : %d %s" % (df.iloc[0]['id'], msg))
    plt.plot(df['X'], df['Y'], 'r')

    min_x = min(df['X'])
    max_x = max(df['X'])

    min_y = min(df['Y'])
    max_y = max(df['Y'])
    plt.axis([min_x - 20, max_x + 20, min_y - 20, max_y + 20])
    plt.plot(df['X'], df['Y'], 'b+')
    plt.tight_layout()
    plt.xlabel('X label')
    plt.ylabel('Y label')
    return plt

def show_3D(df, msg="", pos=[1, 1, 1]):
    fig = plt.figure()
    ax = fig.add_subplot(pos[0], pos[1], pos[2], projection='3d')
    X, Y, Z = df['X'],df['Y'],df['Z']
    ax.plot_wireframe(X, Y, Z)
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    ax.set_title('trajectory ' + str(df['id'].iloc[0]))
    plt.show()

# %%
file = open("Data/Example.txt", "r")
file.readline() # on ignore la première ligne
time, X, Y, Z, id_traj = [], [], [], [], []

for line in file:
    data = re.split('\s', line)
    id_traj.append(int(data[0]))
    time.append(data[1])
    X.append(float(data[2]))
    Y.append(float(data[3]))
    Z.append(float(data[4]))

df = pd.DataFrame(
    {
        "id": id_traj,
        "X": X,
        "time": time,
        "Y": Y,
        "Z": Z
    }
)

# %% [markdown]
# ## Observations
# ### Voici quelques trajectoires supposées juste :

# %%
df_ref = []
id_traj_good = [31, 32, 33, 35, 37, 48]
for i in id_traj_good:
    df_ref.append(df.loc[df['id']==i])

# %%
plt.figure(figsize=(13, 5))
for i in range(1, len(id_traj_good)+1):
    plt.subplot(2, 3, i)
    show_2D(df_ref[i-1])

# %% [markdown]
# ### Et voici celles supposées erronées, à priori :

# %%
df_err = []
id_traj_bad = [28, 29, 30, 40, 41, 42]
for i in id_traj_bad:
    df_err.append(df.loc[df['id']==i])

plt.figure(figsize=(13, 5))
for i in range(1, len(id_traj_bad)+1):
    plt.subplot(2, 3, i)
    show_2D(df_err[i-1])

# %% [markdown]
# ### Remarques
# Au vu des ces trajectoires erronées, nous pouvons observer une concentration importante de points a un endroit donné. Celle-ci révèle que la détection s'est male tournée.
# Contrairement aux trajectoires justes, qui semblent avoir une courbe continue, c'est-à-dire sans perturbements.
#
# ### Hypothèses
# L'idée ici est de comparer l'angle formé par deux vecteurs de points.
# Pour cela nous allons utiliser le Produit Scalaire.

# %% [markdown]
# #### Petit rappel sur les produits scalaires
# Soit deux vecteurs `A` et `b`, le produit scalaire de ceux deux vecteurs est :

# %% [markdown]
# $
# \overrightarrow{A} \cdot \overrightarrow{B} =
# ||\overrightarrow{A}|| * ||\overrightarrow{B}|| *
#     \cos(
#         \overrightarrow{A} , \overrightarrow{B}
#     )
# $
#
# Soit
#
# $
# \cos(\overrightarrow{A},\overrightarrow{B}) =
# \dfrac
#     {\overrightarrow{A} \cdot \overrightarrow{B}}
#     {||\overrightarrow{A}|| \cdot ||\overrightarrow{B}||}
# $
#
# Soit
#
# $
# \angle\overrightarrow{A},\overrightarrow{B} =
# \arccos
#     \Bigg(
#         \dfrac
#             {\overrightarrow{A}\cdot \overrightarrow{B}}
#             {||\overrightarrow{A}|| \cdot ||\overrightarrow{B}||}
#     \Bigg)
# $

# %%
df_ex = df.loc[df['id']==37]

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(df_ex['X'], df_ex['Y'], 'r')

min_x = min(df_ex['X'])
max_x = max(df_ex['X'])
min_y = min(df_ex['Y'])
max_y = max(df_ex['Y'])
plt.axis([min_x - 20, max_x + 20, min_y - 20, max_y + 20])
plt.plot(df_ex['X'], df_ex['Y'], 'b+')
ax.annotate('A', xy=(277, 32), xytext=(285, 40),
                arrowprops=dict(facecolor='black'),
                )
ax.annotate('B', xy=(282, 11), xytext=(290, 30),
                arrowprops=dict(facecolor='black'),
                )
ax.annotate('C', xy=(295, -5), xytext=(300, 5),
                arrowprops=dict(facecolor='black'),
                )
plt.show()

# %% [markdown]
# En ayant les coordonnées A, B et C ci-dessus tels que
#
# $
# A =
# \begin{pmatrix}
# 281.83 \\
# 10.97
# \end{pmatrix}
# ;
# B =
# \begin{pmatrix}
# 276.38 \\
# 32.28
# \end{pmatrix}
# ;
# C =
# \begin{pmatrix}
# 270.89 \\
# 53.59
# \end{pmatrix}
# $
#
# En utilisant la formule ci-dessus, on obtient l'angle $\angle ABC$ valant 157.14

# %%
df_comp = []
df_comp.append(df.loc[df['id']==37])
df_comp.append(df.loc[df['id']==40])

plt.figure(figsize=(10, 4))
for i in range(1, 3):
    plt.subplot(1, 2, i)
    show_2D(df_comp[i-1])

# %% [markdown]
# En observant ces deux trajectoires (celle de gauche supposée juste, celle de droite supposée erronée), nous pouvons observer que, étant donné que la zone erronée est représentée par des un ensemble de points concentrés de points autour d'une certaine région, ces points en question sont relativement "proches", c'est à dire qu'en calculant leur angle, nous devrions trouver un un angle relativement petit. Supposons que cet angle soit inférieur à 50° degré.
# Testons notre hypothèse sur les trajectoires erronées vues précédemment.

# %%
plt.figure(figsize=(13, 5))
for i in range(1, len(id_traj_bad)+1):
    plt.subplot(2, 3, i)
    show_2D(df_err[i-1])

# %% [markdown]
# Voici la fonction permettant de calculer l'angle, dont les valeurs de x et y des vecteurs sont données en paramètres, renvoyant la valeur absolue de l'angle (pour rendre les choses plus simples).
# Réalisons des tests simples.

# %%
import math
def get_angle_vectors(first_vector, second_vector, _3D = False, id_set=False, _id=28):
    cross_product = first_vector[0] * second_vector[0] + first_vector[1] * second_vector[1]
    
    frst_vec_magnitude_squr = (first_vector[0] ** 2 + first_vector[1] ** 2)
    scnd_vec_magnitude_squr = (second_vector[0] ** 2 + second_vector[1] ** 2)
    
    if _3D:
        cross_product +=  first_vector[2] * second_vector[2]
        frst_vec_magnitude_squr += first_vector[2] ** 2
        scnd_vec_magnitude_squr += second_vector[2] ** 2
        
    magnitude = math.sqrt(frst_vec_magnitude_squr * scnd_vec_magnitude_squr)
    
    try:
        angle = math.degrees(math.acos(cross_product / magnitude))
    except ValueError:
        angle = 0

    if angle < 0.01:
        angle = 0
        
    return angle

# %%
# [X, Y, Z]
print(get_angle_vectors([1, 1], [1, 1]))
print(get_angle_vectors([1, 0], [0, 1]))
print(get_angle_vectors([0, 1], [1, 0]))
print(get_angle_vectors([-1, 1], [1, 0]))
print(get_angle_vectors([-1, 0], [1, 0]))
print(get_angle_vectors([0, 0, 1], [1, 1, 0], _3D=True))
# Out:
# 0
# 90.0
# 90.0
# 135.0
# 180.0
# 90.0

# %% [markdown]
# ### Test sur le jeu de données
# Nous réaliserons nos tests sur les 10 premières trajectoires du jeu de données pour commencer, groupant celles qui sont erronées ensemble et le reste ensemble.

# %%
def get_vectors_from_df(df, index, _3D=False):
    size = 3 if _3D else 2
    first_vector = [0 for i in range(size)]
    second_vector = [0 for i in range(size)]
    
    x_previous = df['X'].iloc[index - 1]
    x = df['X'].iloc[index]
    x_next = df['X'].iloc[index + 1]

    y_previous = df['Y'].iloc[index - 1]
    y = df['Y'].iloc[index]
    y_next = df['Y'].iloc[index + 1]

    first_vector[0] = x_previous - x
    first_vector[1] = y_previous - y
    second_vector[0] = x_next - x
    second_vector[1] = y_next - y

    if _3D:
        z_previous = df['Z'].iloc[index - 1]
        z = df['Z'].iloc[index]
        z_next = df['Z'].iloc[index + 1]

        first_vector[2] = z_previous - z
        second_vector[2] = z_next - z
            
    return first_vector, second_vector
            

def get_angles(df, _3D=False):
	ar_angles = []
	for j in range(1, len(df) - 1):
		first_vector, second_vector = get_vectors_from_df(df, j, _3D)
		angle = abs(get_angle_vectors(first_vector, second_vector, _3D))
		ar_angles.append(angle)

	return ar_angles

# %%
id_traj_test = id_traj_bad + id_traj_good

def show_traj_health(array_traj):
    plt.figure(figsize=(13, 5))
    for i in array_traj:
        count_error = 0
        df_test = df[df['id'] == i]
        array_angle = get_angles(df_test, _3D=True)
        for angle in array_angle:
            if angle < 50:
                count_error += 1

        plt.subplot(2, 6, array_traj.index(i) + 1)
        if count_error > 0:
            show_2D(df_test, "(erreur)")
        else:
            show_2D(df_test, "(ok)")
            
show_traj_health(id_traj_test)

# %% [markdown]
# ## Approfondissement
# Ces groupements de points peuvent représenter par exemple l'atterrissage de l'avion, pour qu'il aille à son hangar. Les nombreux détourset voies qu'un avion peut prendre peut expliquer potentiellement expliquer ses points.
# Tout en restant sur cette idée d'angle, nous allons améliorer notre détection en prenant en compte les valeurs moyennes des angles et de vitesse angulaire, en fonction de l'altitude. Cette dernière sera ainsi subdiviser en trois groupes d'altitudes : de 0 à 100 (altitude supposé proche de l'atterrissage), de 100 à 250 (altitude moyenne), et enfin de 250 à 400.

# %%
def get_angles_group_by_altitude(df, _id=28, id_set=False, _3D=False):
	array_angles_alt = [[] for i in range(3)]

	for j in range(1, len(df) - 1):

		first_vector, second_vector = get_vectors_from_df(df, j)

		angle = abs(get_angle_vectors(first_vector, second_vector, id_set, _id, _3D))

		if math.isnan(angle):
			angle = 0

		if df['Z'].iloc[j] < 100:
			array_angles_alt[0].append(angle)
		elif df['Z'].iloc[j] < 250:
			array_angles_alt[1].append(angle)
		else:
			array_angles_alt[2].append(angle)

	return array_angles_alt

# %%
total_array_angle = [[] for i in range(3)]
id_max = max(df['id'])
idd = 28
while idd <= id_max :
    df_id = df[df['id'] == idd]
    if df_id.empty:
        idd += 1
        continue
    array_angles_alt = get_angles_group_by_altitude(df_id, _id=idd, _3D=True)
    total_array_angle[0] += array_angles_alt[0]
    total_array_angle[1] += array_angles_alt[1]
    total_array_angle[2] += array_angles_alt[2]
    idd += 1

avg = [0 for i in range(3)]

# pour éviter le warning si l'array est vide
avg[0] = 0 if len(total_array_angle[0]) == 0 else np.mean(total_array_angle[0])
avg[1] = 0 if len(total_array_angle[1]) == 0 else np.mean(total_array_angle[1])
avg[2] = 0 if len(total_array_angle[2]) == 0 else np.mean(total_array_angle[2])


_altitudes = ('0-100', '100-250', '250-400')


def to_bars(x, y, y_legende, title='Moyenne par altitude'):
    objects = (x)
    y_pos = np.arange(len(objects))
    performance = y
    plt.bar(y_pos, performance, align='center', alpha=0.5, width=0.4)
    plt.xticks(y_pos, objects)
    plt.ylabel(y_legende)
    plt.title(title)

    plt.show()
    
_altitudes = ('0-100', '100-250', '250-400')
to_bars(_altitudes, [avg[0], avg[1], avg[2]], 'Moyenne angle')

# %%
def hms_to_seconds(t):
	h, m, s = [float(i) for i in t.split(':')]
	return 3600*h + 60*m + s


def angular_speed(df):
	if df.empty:
		return 0
	array_angle = get_angles(df, _3D=True)
	# print(array_angle)
	start_time = df['time'].iloc[0]
	end_time = df['time'].iloc[-1]

	s_start_time = hms_to_seconds(start_time)
	s_end_time = hms_to_seconds(end_time)
	s_delta_time = s_end_time - s_start_time
	if len(array_angle) == 0:
		return 0
	avg_angle_speed = np.sum(array_angle) / s_delta_time
	return avg_angle_speed


def angular_speed_by_altitude(df):
	ang_speed_by_alt = [0 for i in range(3)]
	if df.empty:
		return ang_speed_by_alt
	start_time = df['time'].iloc[0]
	end_time = df['time'].iloc[-1]

	ang_speed_by_alt[0] = angular_speed(df[(df['Z'] < 100)])
	ang_speed_by_alt[1] = angular_speed(df[(df['Z'] > 100) & (df['Z'] < 250)])
	ang_speed_by_alt[2] = angular_speed(df[(df['Z'] > 250) & (df['Z'] < 400)])

	return ang_speed_by_alt
    
avg = [[] for i in range(3)]

idd = 28
while idd <= id_max:
    dff = df[df['id'] == idd]
    if dff.empty:
        idd += 1
        continue
    ang_speed_by_alt = angular_speed_by_altitude(dff)
    if ang_speed_by_alt[0] != 0:
        avg[0].append(ang_speed_by_alt[0])
    if ang_speed_by_alt[1] != 0:
        avg[1].append(ang_speed_by_alt[1])
    if ang_speed_by_alt[2] != 0:
        avg[2].append(ang_speed_by_alt[2])
    idd += 1
avgg = [np.nansum(avg[0])/len(avg[0]),
        np.nansum(avg[1])/len(avg[1]),
        np.nansum(avg[2])/len(avg[2])]

to_bars(_altitudes, avgg, 'Moyenne des vitesses angulaires en fontion de l\'altitude')

# %% [markdown]
# En analysant les deux précédents graphes on peut remarquer que les variations d'angles sont plus importantes dans les hautes altitudes plutot, contrairement aux basses altitudes. Ceci peut être expliqué par une certaine manœuvre qu'exécutent les avions dans les hautes altitudes. Elle consiste à réaliser un trajet circulaire autour d’une certaine zone. Le résultat de ce trajet est appelée Dubin-Path (ou Dubin Curve) (cf. image ci-dessous).

# %%
show_3D(df[df['id'] == 40])

# %% [markdown]
# Il existe néanmoins un autre type de trajectoire qui présente de sérieuses anomalies.
# Ici, contrairement à toutes celles vues précédemment, les angles varient de manière très étrange. En effet
# on peut remarquer un changement radical au niveau des directions que prend le trajet. Ces anomalies ont
# été détectées en comparant à chaque changement de signe de la coordonnées Z du vecteur avec son
# prédécesseur. SI cette coordonnée dépasse une certaine valeur, ici 1, la trajectoire est considérée comme
# erronée.
# Les subplots ci-dessous affichent les trajectoires ayant ce genre d'anomalies.

# %%
def z_variations(df):
	count_changed = 0
	up, down = [], []
	z_first = df['Z'].iloc[0]
	z_last = df['Z'].iloc[-1]
	z_current = df['Z'].iloc[1]
	z_previous = z_first

	upwards = z_current > z_previous
	idd = []

	for i in range(2, len(df) - 1):
		z_previous = z_current
		z_current = df['Z'].iloc[i]
		zzz = float(z_current - z_previous)
		if z_current < z_previous  and upwards:
			upwards = False
			count_changed += 1
			down.append(zzz)
		elif z_current > z_previous and not upwards:
			upwards = True
			count_changed += 1
			up.append(zzz)

	return up, down

idd = 28
id_array_z_var = []
while idd <= id_max:
    dff = df[df['id'] == idd]
    if dff.empty:
        idd += 1
        continue
    up, down = z_variations(dff)

    if len(down) > 1 and len(up) > 1 and max(np.abs(down)) > 1 and max(up) > 1:
        id_array_z_var.append(idd)
    idd += 1
    
fig = plt.figure(figsize=(18,9))
for i in range(6):
    ax = fig.add_subplot(2, 3, i+1, projection='3d')
    dff = df[df['id'] == id_array_z_var[i]]
    X, Y, Z = dff['X'],dff['Y'],dff['Z']
    ax.plot_wireframe(X, Y, Z)
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    ax.set_title('trajectory ' + str(dff['id'].iloc[0]))
plt.show()
